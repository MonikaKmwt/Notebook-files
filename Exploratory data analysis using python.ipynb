# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:/Users/monik/Desktop/Prac-Files/TSLA.csv')

# %%
#understanding the data
#check first rows of data
data.head()
# Out:
#    Year Month        Date       Open       High        Low      Close  \
# 0  2017   jan  01-01-2017  14.324000  17.230667  14.064000  16.795334
# 1  2017   feb  01-02-2017  16.870001  19.159332  16.134001  16.666000
# 2  2017   mar  01-03-2017  16.945333  18.799999  16.185333  18.553333
# 3  2017   apr  01-04-2017  19.126667  20.986668  18.972000  20.938000
# 4  2017   may  01-05-2017  20.992001  22.859333  19.384001  22.733999
#
#    Adj Close      Volume
# 0  16.795334  1510194000
# 1  16.666000  1793100000
# 2  18.553333  1605529500
# 3  20.938000  1754259000
# 4  22.733999  2220694500

# %%
#check last rows of data
data.tail()
# Out:
#     Year Month        Date        Open        High         Low       Close  \
# 67  2022   aug  01-08-2022  301.276672  314.666656  271.809998  275.609985
# 68  2022   sep  01-09-2022  272.579987  313.799988  262.470001  265.250000
# 69  2022   oct  01-10-2022  254.500000  257.500000  198.589996  227.539993
# 70  2022   nov  01-11-2022  234.050003  237.399994  166.190002  194.699997
# 71  2022   dec  01-12-2022  197.080002  198.919998  108.239998  123.180000
#
#      Adj Close      Volume
# 67  275.609985  1695263200
# 68  265.250000  1299271000
# 69  227.539993  1735263100
# 70  194.699997  1885275300
# 71  123.180000  2944247700

# %%
#shows number of rows and column
data.shape
# Out:
# (72, 9)

# %%
#shows--Index, DataType, Memory information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       72 non-null     int64
#  1   Month      72 non-null     object
#  2   Date       72 non-null     object
#  3   Open       72 non-null     float64
#  4   High       72 non-null     float64
#  5   Low        72 non-null     float64
#  6   Close      72 non-null     float64
#  7   Adj Close  72 non-null     float64
#  8   Volume     72 non-null     int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 5.2+ KB

# %%
data.head
# Out:
# <bound method NDFrame.head of     Year Month        Date        Open        High         Low       Close  \
# 0   2017   jan  01-01-2017   14.324000   17.230667   14.064000   16.795334
# 1   2017   feb  01-02-2017   16.870001   19.159332   16.134001   16.666000
# 2   2017   mar  01-03-2017   16.945333   18.799999   16.185333   18.553333
# 3   2017   apr  01-04-2017   19.126667   20.986668   18.972000   20.938000
# 4   2017   may  01-05-2017   20.992001   22.859333   19.384001   22.733999
# ..   ...   ...         ...         ...         ...         ...         ...
# 67  2022   aug  01-08-2022  301.276672  314.666656  271.809998  275.609985
# 68  2022   sep  01-09-2022  272.579987  313.799988  262.470001  265.250000
# 69  2022   oct  01-10-2022  254.500000  257.500000  198.589996  227.539993
# 70  2022   nov  01-11-2022  234.050003  237.399994  166.190002  194.699997
# 71  2022   dec  01-12-2022  197.080002  198.919998  108.239998  123.180000
#
#      Adj Close      Volume
# ...

# %%
data.min()
# Out:
# Year               2017
# Month               apr
# Date         01-01-2017
# Open          12.367333
# High          15.649333
# Low           11.799333
# Close            12.344
# Adj Close        12.344
# Volume       1143974700
# dtype: object

# %%
data.max()
# Out:
# Year               2022
# Month               sep
# Date         01-12-2022
# Open         386.899994
# High         414.496674
# Low          326.200012
# Close         381.58667
# Adj Close     381.58667
# Volume       7088802000
# dtype: object

# %%
#Unique values and counts
data.nunique()
# Out:
# Year          6
# Month        12
# Date         72
# Open         72
# High         72
# Low          72
# Close        72
# Adj Close    72
# Volume       72
# dtype: int64

# %%
#Summary statistics of a DataFrame
data.describe()
# Out:
#              Year        Open        High         Low       Close   Adj Close  \
# count    72.00000   72.000000   72.000000   72.000000   72.000000   72.000000
# mean   2019.50000  115.385518  130.000129   97.216167  115.547796  115.547796
# std       1.71981  120.543432  132.294607   99.496338  118.164520  118.164520
# min    2017.00000   12.367333   15.649333   11.799333   12.344000   12.344000
# 25%    2018.00000   20.379166   23.072833   18.959667   20.714999   20.714999
# 50%    2019.50000   26.491333   36.277000   22.863667   31.411000   31.411000
# 75%    2021.00000  230.860832  241.976661  200.525829  226.809998  226.809998
# max    2022.00000  386.899994  414.496674  326.200012  381.586670  381.586670
#
#              Volume
# count  7.200000e+01
# mean   2.646995e+09
# std    1.316220e+09
# min    1.143975e+09
# 25%    1.742479e+09
# 50%    2.156926e+09
# 75%    3.129994e+09
# max    7.088802e+09

# %%
#data.set_index('Date')

# %%
#cleaning the data
#check for null values
pd.notnull('data')
# Out:
# True

# %%
data.isnull().sum()
# Out:
# Year         0
# Month        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#stock data graph

# %%
sns.barplot(x="Year", y="Open", data=data)
plt.title('Opening price per year')
plt.figure(figsize=(6.4,5))

# %%
sns.barplot(x="Year", y="Close", data=data)
plt.title('Closing Price per Year')
# Out:
# Text(0.5, 1.0, 'Closing Price per Year')

# %%
plt.figure(figsize=(6.4,5))
data['High'].plot(label='high', color='green')
data['Low'].plot(label='low',color='orange')
plt.title('comparison between low and high price')
plt.legend()
plt.show()

# %%
'''plt.figure(figsize=(6.4,5))
data['Open'].plot.hist()
plt.legend()
plt.title('Opening Price')'''
# Out:
# "plt.figure(figsize=(6.4,5))\ndata['Open'].plot.hist()\nplt.legend()\nplt.title('Opening Price')"

# %%
'''plt.figure(figsize=(6.4,5))
data['Close'].plot.hist()
plt.legend()
plt.title('Closing Price')'''
# Out:
# "plt.figure(figsize=(6.4,5))\ndata['Close'].plot.hist()\nplt.legend()\nplt.title('Closing Price')"

# %%
#stock data line graph comparison
plt.figure(figsize=(6.4,5))
data['Open'].plot()
data['Close'].plot()
plt.title('Comparison between Opening and closing price')
plt.legend()
plt.show()

# %%
'''plt.figure(figsize=(8,5))
data['Low'].plot()
plt.show()'''
# Out:
# "plt.figure(figsize=(8,5))\ndata['Low'].plot()\nplt.show()"

# %%
'''plt.figure(figsize=(8,5))
data['High'].plot()
plt.show()
# Out:
# "plt.figure(figsize=(8,5))\ndata['High'].plot()\nplt.show()"

# %%
#sns[data].boxplot(x='Date', y='Close')

# %%
#data['Open'].median()

# %%
data.plot.scatter(x='Open', y='Close')
plt.title('correlation between opening and closing price')
# Out:
# Text(0.5, 1.0, 'correlation between opening and closing price')

# %%
sns.stripplot(x='Year', y='Volume', color='red', data=data)
plt.title('type of correlation')
# Out:
# Text(0.5, 1.0, 'type of correlation')

# %%
sns.barplot(x="Year", y="Volume", data=data)
plt.title('Volume per Year')
# Out:
# Text(0.5, 1.0, 'Volume per Year')

# %%
#sns.histplot(data['Volume'])

# %%
tesla = data.drop(['Date','Month','Adj Close'],axis=1)

# %%
correlation = tesla.corr()

# %%
sns.heatmap(correlation, xticklabels=correlation.columns,
            yticklabels=correlation.columns, annot=True)
# Out:
# <Axes: >

# %%
#sns.boxplot(x='Month', y='High', data=data)

# %%
#sns.distplot(data['Volume'], bins=5)

# %%
#sns.catplot(x='Open', kind='box', data=data)
